# %% [markdown]
# # Знайомство з даними

# %%
# !gdown --id 1AEZJUW-JCbBn9oIRnyL2jYmJrGPHJZRj
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1AEZJUW-JCbBn9oIRnyL2jYmJrGPHJZRj
# To: /content/order_reviews.csv
# 100% 14.4M/14.4M [00:00<00:00, 33.2MB/s]

# %%
# !gdown --id 11V5_01mPWjYV0x2drDdNF4oCNigOZMmG
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=11V5_01mPWjYV0x2drDdNF4oCNigOZMmG
# To: /content/order_payments.csv
# 100% 5.78M/5.78M [00:00<00:00, 69.3MB/s]

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import RSLPStemmer
import string
import re
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import numpy as np
import seaborn as sns
import xgboost as xgb

# %% [markdown]
# Читаємо файли з відгуками та сумами замовлень

# %%
reviews = pd.read_csv('/content/order_reviews.csv')
payments = pd.read_csv('/content/order_payments.csv')

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_comment_title     11715 non-null   object
#  4   review_comment_message   41753 non-null   object
#  5   review_creation_date     100000 non-null  object
#  6   review_answer_timestamp  100000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# Присутні відгуки без тексту, відразу їх відкидаємо

# %%
reviews = reviews.dropna(subset='review_comment_message')

# %% [markdown]
# Перевіряємо платежі на дуплікати id

# %%
payments[payments.duplicated(subset='order_id', keep = False)].sort_values(by='order_id')
# Out:
#                                order_id  payment_sequential payment_type  \
# 80856  0016dfedd97fc2950e388d2971d718c7                   2      voucher
# 89575  0016dfedd97fc2950e388d2971d718c7                   1  credit_card
# 20036  002f19a65a2ddd70a090297872e6d64e                   1      voucher
# 98894  002f19a65a2ddd70a090297872e6d64e                   2      voucher
# 30155  0071ee2429bc1efdc43aa3e073a5290e                   2      voucher
# ...                                 ...                 ...          ...
# 21648  ffa1dd97810de91a03abd7bd76d2fed1                   2      voucher
# 32912  ffa39020fe7c8a3e907320e1bec4b985                   1  credit_card
# 3009   ffa39020fe7c8a3e907320e1bec4b985                   2      voucher
# 75188  ffc730a0615d28ec19f9cad02cb41442                   1  credit_card
# 28537  ffc730a0615d28ec19f9cad02cb41442                   2  credit_card
#
#        payment_installments  payment_value
# 80856                     1          17.92
# 89575                     5          52.63
# 20036                     1          44.11
# 98894                     1          33.18
# 30155                     1          92.44
# ...                     ...            ...
# 21648                     1         418.73
# 32912                     1           7.13
# 3009                      1          64.01
# 75188                     1          14.76
# 28537                     1          12.63
#
# [7407 rows x 5 columns]

# %% [markdown]
# З'єднуємо інформацію про сплату з таблицею відгуків

# %%
payments_sum = pd.DataFrame(payments.groupby('order_id')['payment_value'].agg('sum'))
reviews = reviews.merge(payments_sum.payment_value, on = 'order_id', how='inner').copy()

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41752 entries, 0 to 41751
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                41752 non-null  object
#  1   order_id                 41752 non-null  object
#  2   review_score             41752 non-null  int64
#  3   review_comment_title     9986 non-null   object
#  4   review_comment_message   41752 non-null  object
#  5   review_creation_date     41752 non-null  object
#  6   review_answer_timestamp  41752 non-null  object
#  7   payment_value            41752 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.5+ MB

# %%
reviews.head(10)
# Out:
#                           review_id                          order_id  \
# 0  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 1  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 2  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 3  4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 4  3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
# 5  9314d6f9799f5bfba510cc7bcd468c01  0dacf04c5ad59fd5a0cc1faa07c34e39
# 6  373cbeecea8286a2b66c97b1b157ec46  583174fbe37d3d5f0d6661be3aad1786
# 7  d21bbc789670eab777d27372ab9094cc  4fc44d78867142c627497b60a7e0228a
# 8  0e0190b9db53b689b285d3f3916f8441  79832b7cb59ac6f887088ffd686e1d5e
# 9  fe3db7c069d694bab50cc43463f91608  2ca73e2ff9e3a186ad1e1ffb9b1d9c10
#
#    review_score     review_comment_title  \
# 0             5                      NaN
# 1             5                      NaN
# 2             4                recomendo
# 3             4                      NaN
# 4             5          Super recomendo
# 5             2                      NaN
# 6             1  Não chegou meu produto
# 7             5                    Ótimo
# 8             5                      NaN
# 9             5                      NaN
#
#                               review_comment_message review_creation_date  \
# 0              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 1  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# 2  aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
# 3    Mas um pouco ,travando...pelo valor ta Boa.\r\n  2018-02-16 00:00:00
# 4  Vendedor confiável, produto ok e entrega antes...  2018-05-23 00:00:00
# 5  GOSTARIA DE SABER O QUE HOUVE, SEMPRE RECEBI E...  2018-01-18 00:00:00
# 6                                            Péssimo  2018-08-15 00:00:00
# 7                                       Loja nota 10  2018-07-10 00:00:00
# 8              obrigado pela atençao amim dispensada  2017-12-01 00:00:00
# 9  A compra foi realizada facilmente.\r\nA entreg...  2018-03-23 00:00:00
#
#   review_answer_timestamp  payment_value
# 0     2017-04-21 22:02:06         222.84
# 1     2018-03-02 10:26:53        1333.25
# 2     2018-05-23 16:45:47         613.25
# 3     2018-02-20 10:52:22          42.78
# 4     2018-05-24 03:00:01         103.06
# 5     2018-01-20 21:25:45         188.65
# 6     2018-08-15 04:10:37          99.28
# 7     2018-07-11 14:10:25          65.24
# 8     2017-12-09 22:58:58          79.56
# 9     2018-04-01 00:27:51         179.87

# %% [markdown]
# # Аналіз сплат за замовлення

# %%
reviews.describe()
# Out:
#        review_score  payment_value
# count  41752.000000   41752.000000
# mean       3.640472     172.448021
# std        1.626351     244.014729
# min        1.000000       0.000000
# 25%        2.000000      64.880000
# 50%        4.000000     110.765000
# 75%        5.000000     187.530000
# max        5.000000   13664.080000

# %%
fig, axes = plt.subplots(1, 2, figsize = (10,10))

axes[0].hist(reviews['payment_value'], bins = 50)
axes[0].set_title('Розподілення сплат за замовлення')
axes[1].boxplot(reviews['payment_value'])
axes[1].set_title('Боксплот розподілення сплат за замовлення')
# Out:
# Text(0.5, 1.0, 'Боксплот розподілення сплат за замовлення')

# %% [markdown]
# Бачимо великі викиди. Порахуємо відсоток викидів від усіх сплат

# %%
Q1 = reviews['payment_value'].quantile(0.25)
Q3 = reviews['payment_value'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
np.mean((reviews['payment_value'] < lower_bound) | (reviews['payment_value'] > upper_bound))
# Out:
# 0.08143322475570032

# %% [markdown]
# Викиди ставлять лише 8 відцотків від усіх даних. Очистимо дані від них

# %%
reviews = reviews[(reviews['payment_value'] >= lower_bound) & (reviews['payment_value'] <= upper_bound)]

# %%
reviews.describe()
# Out:
#        review_score  payment_value
# count  38352.000000   38352.000000
# mean       3.666693     121.288182
# std        1.613791      76.826753
# min        1.000000       0.000000
# 25%        2.000000      62.050000
# 50%        4.000000     102.030000
# 75%        5.000000     163.165000
# max        5.000000     371.420000

# %%
fig, axes = plt.subplots(1, 2, figsize = (10,10))

axes[0].hist(reviews['payment_value'], bins = 50)
axes[0].set_title('Розподілення сплат за замовлення')
axes[1].boxplot(reviews['payment_value'])
axes[1].set_title('Боксплот розподілення сплат за замовлення')
# Out:
# Text(0.5, 1.0, 'Боксплот розподілення сплат за замовлення')

# %% [markdown]
# # Транформація текстових даних

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('rslp')
stop_words = set(stopwords.words('portuguese'))
stemmer = RSLPStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.

# %% [markdown]
# Функція преведення тексту до нижнього регістру, видалення усіх непотрібних символів, стоп слів. Подальша токенізація та стеммінг.

# %%
def preprocess_text(text):

    text = text.lower()

    text = text.translate(str.maketrans('', '', string.punctuation + string.digits))

    text = re.sub(r'[^a-zA-ZáéíóúãõçÁÉÍÓÚÃÕÇ\s]', '', text)

    tokens = word_tokenize(text)

    tokens = [stemmer.stem(word) for word in tokens if word.strip() and word.lower() not in stop_words]

    return ' '.join(tokens)

# %%
reviews['processed_review_comment_message'] = reviews['review_comment_message'].apply(preprocess_text)

# %% [markdown]
# Оброблені відгуки

# %%
reviews['processed_review_comment_message'].head(10)
# Out:
# 0                            receb bem ant praz estipul
# 3                           pouc travandopel val ta boa
# 4                  vend confi produt ok entreg ant praz
# 5              gost sab sempr receb compr agor decpcion
# 6                                                  péss
# 7                                               loj not
# 8                             obrig atença amim dispens
# 9     compr realiz facil entreg efetu ant praz dad p...
# 10                                   relógi bonit barat
# 11                                  gost compr gat lebr
# Name: processed_review_comment_message, dtype: object

# %% [markdown]
# Найпопулярніші слова у відгуках

# %%
all_reviews = ' '.join(reviews['processed_review_comment_message'])
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap = 'Accent').generate_from_frequencies(Counter(word_tokenize(all_reviews)))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Розмітка класів

# %% [markdown]
# Промітимо відгуки за значенням оцінки товару(1,2 як негативний, 3,4,5 як позитивний)

# %%
reviews['positivity_score'] = reviews['review_score'].map({1:0 , 2:0, 3:1, 4:1, 5:1})

# %% [markdown]
# Найпопулярніші слова у позитивних відгуках

# %%
all_pos_reviews = ' '.join(reviews[reviews['positivity_score'] == 1].processed_review_comment_message)
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap = 'Greens').generate_from_frequencies(Counter(word_tokenize(all_pos_reviews)))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Найпопулярніші слова у негативних відгуках

# %%
all_neg_reviews = ' '.join(reviews[reviews['positivity_score'] == 0].processed_review_comment_message)
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap = 'Reds').generate_from_frequencies(Counter(word_tokenize(all_neg_reviews)))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Ділимо дані на тренувальні та тестові

# %%
X_train, X_test, y_train, y_test = train_test_split\
(reviews.processed_review_comment_message, reviews[['positivity_score','payment_value']],\
 test_size=0.2, random_state=123, stratify=reviews.positivity_score)

# %% [markdown]
# Тансформуємо текст у tf idf вектори

# %%
vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %% [markdown]
# # Побудова та оцінка класифікатора

# %% [markdown]
# Вводимо класифікатор, навчаємо його та робимо передбачення на тестовій виборці.
# Відображаємо метрики якості моделі.

# %%
logreg = LogisticRegression(random_state=123)
logreg.fit(X_train_tfidf, y_train['positivity_score'])
y_pred = logreg.predict(X_test_tfidf)

print(classification_report(y_test['positivity_score'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78      2039
#            1       0.92      0.93      0.92      5632
#
#     accuracy                           0.89      7671
#    macro avg       0.86      0.85      0.85      7671
# weighted avg       0.88      0.89      0.88      7671

# %% [markdown]
# Добавимо у класифікатор третій класс відповідаючий до нейтрального коментаря. Коментар буде помічатися нейтральним якщо ймовірність надлежати до першого класу знаходится на відрізку [0.3 ; 0.7]. Негативний та позитивний відповідно нижче та вище за ці границі.

# %%
prob = logreg.predict_proba(X_test_tfidf)
prob_pred = [0 if i < 0.3 else 2 if 0.3 <= i <= 0.7 else 1 for i in prob[:,1]]
test = pd.DataFrame({'pred': prob_pred, 'true': y_test['positivity_score']})
test2 = test[test['pred'] != 2]
print(classification_report(test2.pred, test2.true))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86      1296
#            1       0.96      0.96      0.96      5056
#
#     accuracy                           0.94      6352
#    macro avg       0.91      0.91      0.91      6352
# weighted avg       0.94      0.94      0.94      6352

# %%
reviews['pred'] = test['pred']

# %% [markdown]
# Графічна оцінка класифікатора

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

data = reviews.groupby('pred')['pred'].count()
axes[0,0].pie(data, autopct='%1.1f%%',colors = ['yellow','green','red'])
axes[0,0].legend(data.index.map({0:'Негативні',1:'Позитивні',2:'Нейтральні'}))
axes[0,0].set_title('Розподіл кометарів')

colors = ['green','blue','yellow','orange','red']

data = reviews[reviews['pred'] == 1].groupby('review_score')['review_score'].count()
axes[0,1].pie(data, autopct='%1.1f%%',colors=colors[::-1])
axes[0,1].legend(data.index)
axes[0,1].set_title('Розподіл оцінок для позитивних коментарів')

data = reviews[reviews['pred'] == 0].groupby('review_score')['review_score'].count()
axes[1,0].pie(data, autopct='%1.1f%%',colors=colors[::-1])
axes[1,0].legend(data.index)
axes[1,0].set_title('Розподіл оцінок для негативних коментарів')

data = reviews[reviews['pred'] == 2].groupby('review_score')['review_score'].count()
axes[1,1].pie(data, autopct='%1.1f%%',colors=colors[::-1])
axes[1,1].legend(data.index)
axes[1,1].set_title('Розподіл оцінок для нейтральних коментарів')
# Out:
# Text(0.5, 1.0, 'Розподіл оцінок для нейтральних коментарів')

# %% [markdown]
# # Побудова та оцінка регресора

# %%
boost = xgb.XGBRegressor(colsample_bytree= 0.6, learning_rate= 0.1, max_depth= 5, n_estimators= 200, subsample= 1.0)
boost.fit(X_train_tfidf, y_train['payment_value'])
y_pred = boost.predict(X_test_tfidf)
mae = mean_absolute_error(y_test['payment_value'],y_pred)

# %%
print(f'Середнья помилка моделі : {mae}')
# Out:
# Середнья помилка моделі : 60.29892539871608

# %% [markdown]
# Візуалізація роботи моделі

# %%
sns.displot(y_test['payment_value'], bins = 50)
plt.hist(y_pred, bins = 200, color='green')
# Out:
# (array([1.00e+00, 0.00e+00, 1.00e+00, 2.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 2.00e+00, 0.00e+00, 2.00e+00, 0.00e+00, 1.00e+00,
#         0.00e+00, 2.00e+00, 0.00e+00, 0.00e+00, 1.00e+00, 1.00e+00,
#         0.00e+00, 2.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00,
#         2.00e+00, 2.00e+00, 2.00e+00, 1.00e+00, 1.00e+00, 1.00e+00,
#         0.00e+00, 6.00e+00, 3.00e+00, 2.00e+00, 1.00e+00, 3.00e+00,
#         2.00e+00, 5.00e+00, 2.00e+00, 1.00e+00, 0.00e+00, 3.00e+00,
#         4.00e+00, 5.00e+00, 5.00e+00, 4.00e+00, 1.00e+00, 2.00e+00,
#         6.00e+00, 4.00e+00, 3.00e+00, 5.00e+00, 3.00e+00, 4.00e+00,
#         1.00e+00, 9.00e+00, 2.10e+01, 1.40e+01, 1.00e+01, 1.00e+01,
#         5.00e+00, 1.70e+01, 2.20e+01, 1.80e+01, 2.20e+01, 2.70e+01,
#         7.80e+01, 3.20e+01, 7.50e+01, 8.90e+01, 1.40e+02, 1.06e+02,
#         2.89e+02, 6.22e+02, 2.20e+03, 5.42e+02, 2.97e+02, 3.42e+02,
#         3.51e+02, 1.93e+02, 1.73e+02, 1.63e+02, 9.80e+01, 1.57e+02,
#         1.15e+02, 9.70e+01, 1.06e+02, 8.60e+01, 7.20e+01, 5.50e+01,
#         5.10e+01, 6.50e+01, 6.30e+01, 4.60e+01, 3.80e+01, 4.20e+01,
#         4.60e+01, 5.00e+01, 2.40e+01, 2.10e+01, 2.40e+01, 3.10e+01,
#         2.40e+01, 1.90e+01, 2.70e+01, 1.50e+01, 1.80e+01, 2.00e+01,
#         1.10e+01, 1.50e+01, 1.40e+01, 1.40e+01, 1.20e+01, 1.40e+01,
#         1.10e+01, 1.10e+01, 9.00e+00, 1.30e+01, 6.00e+00, 8.00e+00,
#         1.10e+01, 6.00e+00, 1.00e+01, 8.00e+00, 8.00e+00, 5.00e+00,
#         3.00e+00, 9.00e+00, 8.00e+00, 8.00e+00, 4.00e+00, 4.00e+00,
#         8.00e+00, 2.00e+00, 4.00e+00, 4.00e+00, 4.00e+00, 6.00e+00,
#         1.00e+00, 5.00e+00, 1.00e+00, 3.00e+00, 1.00e+00, 2.00e+00,
#         0.00e+00, 2.00e+00, 2.00e+00, 3.00e+00, 0.00e+00, 1.00e+00,
#         2.00e+00, 0.00e+00, 1.00e+00, 2.00e+00, 0.00e+00, 1.00e+00,
#         1.00e+00, 0.00e+00, 2.00e+00, 0.00e+00, 2.00e+00, 1.00e+00,
#         3.00e+00, 1.00e+00, 0.00e+00, 0.00e+00, 2.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00, 0.00e+00, 0.00e+00,
#         1.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 1.00e+00]),
#  array([ 35.32419586,  36.33444595,  37.34469604,  38.35494995,
#          39.36520004,  40.37545013,  41.38570023,  42.39595032,
#          43.40620422,  44.41645432,  45.42670441,  46.4369545 ,
#          47.4472084 ,  48.4574585 ,  49.46770859,  50.47795868,
#          51.48820877,  52.49846268,  53.50871277,  54.51896286,
#          55.52921295,  56.53946304,  57.54971695,  58.55996704,
#          59.57021713,  60.58046722,  61.59071732,  62.60097122,
#          63.61122131,  64.62147522,  65.6317215 ,  66.6419754 ,
#          67.65222168,  68.66247559,  69.67272949,  70.68297577,
#          71.69322968,  72.70347595,  73.71372986,  74.72398376,
#          75.73423004,  76.74448395,  77.75473022,  78.76498413,
#          79.77523804,  80.78548431,  81.79573822,  82.8059845 ,
#          83.8162384 ,  84.82649231,  85.83673859,  86.84699249,
#          87.85723877,  88.86749268,  89.87774658,  90.88799286,
#          91.89824677,  92.90849304,  93.91874695,  94.92900085,
#          95.93924713,  96.94950104,  97.95975494,  98.97000122,
#          99.98025513, 100.9905014 , 102.00075531, 103.01100922,
#         104.02125549, 105.0315094 , 106.04175568, 107.05200958,
#         108.06226349, 109.07250977, 110.08276367, 111.09300995,
#         112.10326385, 113.11351776, 114.12376404, 115.13401794,
#         116.14426422, 117.15451813, 118.16477203, 119.17501831,
#         120.18527222, 121.19551849, 122.2057724 , 123.21602631,
#         124.22627258, 125.23652649, 126.24677277, 127.25702667,
#         128.26727295, 129.27752686, 130.28778076, 131.29803467,
#         132.30828857, 133.31852722, 134.32878113, 135.33903503,
#         136.34928894, 137.35954285, 138.36978149, 139.3800354 ,
#         140.39028931, 141.40054321, 142.41079712, 143.42103577,
#         144.43128967, 145.44154358, 146.45179749, 147.46205139,
#         148.47229004, 149.48254395, 150.49279785, 151.50305176,
#         152.51330566, 153.52354431, 154.53379822, 155.54405212,
#         156.55430603, 157.56455994, 158.57479858, 159.58505249,
#         160.5953064 , 161.6055603 , 162.61581421, 163.62605286,
#         164.63630676, 165.64656067, 166.65681458, 167.66706848,
#         168.67730713, 169.68756104, 170.69781494, 171.70806885,
#         172.71832275, 173.7285614 , 174.73881531, 175.74906921,
#         176.75932312, 177.76957703, 178.77981567, 179.79006958,
#         180.80032349, 181.81057739, 182.8208313 , 183.83106995,
#         184.84132385, 185.85157776, 186.86183167, 187.87208557,
#         188.88232422, 189.89257812, 190.90283203, 191.91308594,
#         192.92333984, 193.93357849, 194.9438324 , 195.9540863 ,
#         196.96434021, 197.97459412, 198.98484802, 199.99508667,
#         201.00534058, 202.01559448, 203.02584839, 204.03610229,
#         205.04634094, 206.05659485, 207.06684875, 208.07710266,
#         209.08735657, 210.09759521, 211.10784912, 212.11810303,
#         213.12835693, 214.13861084, 215.14884949, 216.15910339,
#         217.1693573 , 218.17961121, 219.18986511, 220.20010376,
#         221.21035767, 222.22061157, 223.23086548, 224.24111938,
#         225.25135803, 226.26161194, 227.27186584, 228.28211975,
#         229.29237366, 230.3026123 , 231.31286621, 232.32312012,
#         233.33337402, 234.34362793, 235.35386658, 236.36412048,
#         237.37437439]),
#  <BarContainer object of 200 artists>)

# %% [markdown]
# # Фінальна функція для оцінки сплати через текст

# %%
def TextToPayment(text):
  text = preprocess_text(text)

  return boost.predict(vectorizer.transform(np.array([text])))

# %%
text = 'obrigado pela atençao amim dispensada'
TextToPayment(text)
# Out:
# array([117.35006], dtype=float32)
